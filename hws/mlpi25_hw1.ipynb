# %% [markdown]
# <p align="left">
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/feng_heading_en.png" width=400 alt="Feng heading"/>
# </p>
#
# #### Homework 1 :
# <p />01211373 Machine Learning and Programming for Industry
# <p />Academic year 2025. First semester.
#
# **Important :** Type your name and student ID in the cell below. (Failing to do so results in -1 point penalty.)

# %%
# student's name - surname,  ID

# %%
# import libraries you want to use
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ***
# ### List of Homework problems (total 10 points)
#
# * [P1. (3 points)](#p1)
# * [P2. (3 points)](#p2)
# * [P3. (4 points)](#p3)

# %% [markdown]
# <a id="p1"></a>
# #### P1. (3 points)
#
# Figure 1 shows a diagram of perceptron.
#
# !["fig 1"](https://raw.githubusercontent.com/rasbt/machine-learning-book/refs/heads/main/ch02/figures/02_04.png)
#
# <div align="center"><b>Figure 1 a perceptron diagram</b></div>
#
# From class we learn to implement an OOP perceptron in Python. Use the code from book's github to classify 2 classes of iris dataset, but change one sample of the dataset so that they are not linearly separable. Run the perceptron algorithm for about 50 iterations to show that it does not converge.
#
# ### Solution

# %% [markdown]
# <a id="p2"></a>
# #### P2. (3 points)
#
# Figure 2 shows an adaptive linear neuron (Adaline) compared to perceptron.
#
# !["fig 2"](https://raw.githubusercontent.com/rasbt/machine-learning-book/refs/heads/main/ch02/figures/02_09.png)
#
# <div align="center"><b>Figure 2 comparison beween perceptron and Adaline</b></div>
#
# From class we learn how to implement an OOP Adaline. Modify the code from book's github to add a step method to observe each iteration of Adaline. Execute
# ```python
# adaline.step(X_std,y)
# ```
# to see the progress of decision region. X_std is the feature after standardization.
#
# ### Solution

# %% [markdown]
# <a id="p3"></a>
# #### P3. (4 points)
#
# In the stochastic gradient descent (AdalineSGD) class, modify it to add step() method as in
# P2. Also, implement the adaptive learning rate for SGD on page 46 of book. Add an optional
# argument such as adaptive_lr=True to turn on the adaptive learning. (3 points)
#
# There is a method already implemented called partial_fit(). Explain the difference between
# partial_fit() and step() (1 point)
#
# ### Solution

# %% [markdown]
# ##### Rev. 1A : August 2025

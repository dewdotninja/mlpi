# %% [markdown]
# <p align="left">
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/feng_heading_en.png" width=400 alt="Feng heading"/>
# </p>
#
# #### Homework 3 :
# <p />01211373 Machine Learning and Programming for Industry
# <p />Academic year 2025. First semester.
#
# **Important :** Type your name and student ID in the cell below. (Failing to do so results in -1 point penalty.)

# %%
# student's name - surname,  ID

# %%
# import libraries you want to use
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ***
# ### List of Homework problems (total 10 points)
#
# * [P1. (5 points)](#p1)
# * [P2. (5 points)](#p2)

# %% [markdown]
# <a id="p1"></a>
# #### P1. (5 points)
#
# Use k-nearest neighbor algorithm for classification of a dataset of your choice. For example, any dataset from kaggle
#
# https://www.kaggle.com/datasets?tags=13302-Classification
#
# You can choose either binary or multi-class classification.
#
# **Note :** In the link above there are a lot of datasets to play around with. I strongly recommend that you choose a different dataset from your friends. When your work is unique, I have no doubt that you do it by yourself and will take that into consideration.
#
# **Important :** you *cannot* use **"Alzheimer's Disease Dataset"** because it is used as a demo in class. Using this dataset will result in zero score for this subproblem!
#
# In order to plot data samples on 2D graph, choose only 2 features that simplifies your classification task. You may prefer continuous features. You should initially plot the samples to judge whether your selection is good enough.
#
# Split your data to training and testing sets, say, 70/30.
#
# Evaluate the train and test accuracy, and plot the data samples versus the decision boundary, for both train and test data.

# %% [markdown]
# ### Solution

# %%
# Install kagglehub if you have not done so.
#!pip install kagglehub

# %%
import kagglehub
import os

# Download latest version of the dataset
path = kagglehub.dataset_download("your choice")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 268k/268k [00:00<00:00, 410kB/s]
# Extracting files...
# Path to dataset files: /Users/dewdotninja/.cache/kagglehub/datasets/rabieelkharoua/alzheimers-disease-dataset/versions/1

# %%
try:
    df = pd.read_csv(os.path.join(path, "your_dataset.csv"))
except FileNotFoundError:
    print("Error: heart.csv not found. Please ensure the dataset is in the same directory.")
    exit()

# %% [markdown]
# <a id="p2"></a>
# #### P2. (5 points)
#
# Scikit-learn comes with a few toy datasets for ML. One is the so called "moons dataset." Load 1500 samples of the data, with noise=0.15, and plot in 2D. The two classed must show in different colors. Then split the data with 70% training and 30% testing. Make sure that the train and test data have equal number of samples for each class.
#
# P2.1 (2 points) Use Scikit-learn 's support vector machine, with linear kernel, to do binary classification. Evaluate the accuracy. Plot decision boundary.
#
# P2.2 (2 points) Use the kernel trick to learn nonlinear boundary of this dataset. Evaluate the accuracy.
# Plot decision boundary.
#
# P2.3 (1 point) Explain how the kernel trick helps with classification of the moon dataset.
#
# ### Solution

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <div align="center">
# <img src="https://raw.githubusercontent.com/dewdotninja/sharing-github/refs/heads/master/dewninja_logo50.jpg" alt="dewninja"/>
# </div>
# <div align="center">dew.ninja 2025</div>

# %% [markdown]
# ##### Rev. 1A : August 2025
